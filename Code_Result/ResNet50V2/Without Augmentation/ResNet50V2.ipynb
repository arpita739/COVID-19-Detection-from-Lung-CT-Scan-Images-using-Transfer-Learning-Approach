# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/COVID/kaggledataset
# Out:
# /content/drive/My Drive/COVID/kaggledataset

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas.util.testing as tm

import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#define size to which images are to be resized
IMAGE_SIZE = [224, 224] # feel free to change depending on dataset

# training config:
epochs = 500
batch_size = 32

#define paths
covid_path = '/content/drive/My Drive/COVID/kaggledataset/COVID'
noncovid_path = '/content/drive/My Drive/COVID/kaggledataset/non-COVID'

# Use glob to grab images from path .jpg or jpeg
covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Visualize file variable contents
print("First 5 Covid Files: ",covid_files[0:5])
print("Total Count: ",len(covid_files))
print("First 5 NonCovid Files: ",noncovid_files[0:5])
print("Total Count: ",len(noncovid_files))
# Out:
# First 5 Covid Files:  ['/content/drive/My Drive/COVID/kaggledataset/COVID/Covid (1244).png', '/content/drive/My Drive/COVID/kaggledataset/COVID/Covid (128).png', '/content/drive/My Drive/COVID/kaggledataset/COVID/Covid (1219).png', '/content/drive/My Drive/COVID/kaggledataset/COVID/Covid (1229).png', '/content/drive/My Drive/COVID/kaggledataset/COVID/Covid (1202).png']
# Total Count:  1252
# First 5 NonCovid Files:  ['/content/drive/My Drive/COVID/kaggledataset/non-COVID/Non-Covid (1185).png', '/content/drive/My Drive/COVID/kaggledataset/non-COVID/Non-Covid (1211).png', '/content/drive/My Drive/COVID/kaggledataset/non-COVID/Non-Covid (1226).png', '/content/drive/My Drive/COVID/kaggledataset/non-COVID/Non-Covid (117).png', '/content/drive/My Drive/COVID/kaggledataset/non-COVID/Non-Covid (1170).png']
# Total Count:  1229

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per kera
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') # append class label
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
# Convert to array and Normalize to interval of [0,1]
covid_images = np.array(covid_images) / 255
noncovid_images = np.array(noncovid_images) / 255

# %%
# split into training and testing
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)


X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
m = ResNet50V2(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = m.output
outputs= AveragePooling2D((2,2),strides=(2,2))(outputs)
outputs = Flatten(name="flatten")(outputs)
outputs = Dense(128, activation="relu")(outputs)
outputs = Dropout(0.3)(outputs)
outputs = Dense(64, activation="relu")(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=m.input, outputs=outputs)

for layer in m.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

# %%
# Visualize Model
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 56, 56, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 56, 56, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 56, 56, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 56, 56, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 56, 56, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 56, 56, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 56, 56, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 28, 28, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 28, 28, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 28, 28, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 28, 28, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 28, 28, 256)  0           max_pooling2d_3[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 28, 28, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 28, 28, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 28, 28, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 14, 14, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 14, 14, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 14, 14, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 512)  0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 14, 14, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 14, 14, 512)  0           max_pooling2d_4[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 14, 14, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 14, 14, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 7, 7, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 7, 7, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 7, 7, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 1024)   0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 7, 7, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 7, 7, 1024)   0           max_pooling2d_5[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 7, 7, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 7, 7, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 7, 7, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 7, 7, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 7, 7, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 7, 7, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 7, 7, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 7, 7, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 3, 3, 2048)   0           post_relu[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 18432)        0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          2359424     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            130         dense_4[0][0]
# ==================================================================================================
# Total params: 25,932,610
# Trainable params: 2,367,810
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=batch_size,
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / batch_size,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=epochs)
# Out:
# Epoch 1/500
#  2/62 [..............................] - ETA: 3s - loss: 4.8198 - accuracy: 0.5625WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0139s vs `on_train_batch_end` time: 0.0436s). Check your callbacks.
# 62/62 [==============================] - 5s 84ms/step - loss: 1.0622 - accuracy: 0.6668 - val_loss: 0.3810 - val_accuracy: 0.8592
# Epoch 2/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.3501 - accuracy: 0.8508 - val_loss: 0.2478 - val_accuracy: 0.9014
# Epoch 3/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.2301 - accuracy: 0.9002 - val_loss: 0.2336 - val_accuracy: 0.9074
# Epoch 4/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.1532 - accuracy: 0.9385 - val_loss: 0.1763 - val_accuracy: 0.9336
# Epoch 5/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.1154 - accuracy: 0.9526 - val_loss: 0.2257 - val_accuracy: 0.9215
# Epoch 6/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0975 - accuracy: 0.9546 - val_loss: 0.1967 - val_accuracy: 0.9256
# Epoch 7/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0753 - accuracy: 0.9713 - val_loss: 0.2368 - val_accuracy: 0.9296
# Epoch 8/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0548 - accuracy: 0.9793 - val_loss: 0.2443 - val_accuracy: 0.9296
# Epoch 9/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0592 - accuracy: 0.9763 - val_loss: 0.3638 - val_accuracy: 0.9296
# Epoch 10/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0487 - accuracy: 0.9829 - val_loss: 0.2129 - val_accuracy: 0.9376
# Epoch 11/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0713 - accuracy: 0.9682 - val_loss: 0.2256 - val_accuracy: 0.9155
# Epoch 12/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0498 - accuracy: 0.9819 - val_loss: 0.2361 - val_accuracy: 0.9376
# Epoch 13/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0361 - accuracy: 0.9869 - val_loss: 0.1949 - val_accuracy: 0.9396
# Epoch 14/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0453 - accuracy: 0.9829 - val_loss: 0.2559 - val_accuracy: 0.9256
# Epoch 15/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0386 - accuracy: 0.9834 - val_loss: 0.2046 - val_accuracy: 0.9416
# Epoch 16/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0376 - accuracy: 0.9844 - val_loss: 0.2511 - val_accuracy: 0.9416
# Epoch 17/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0323 - accuracy: 0.9884 - val_loss: 0.1861 - val_accuracy: 0.9336
# Epoch 18/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0399 - accuracy: 0.9839 - val_loss: 0.2733 - val_accuracy: 0.9256
# Epoch 19/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0689 - accuracy: 0.9743 - val_loss: 0.2687 - val_accuracy: 0.9276
# Epoch 20/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0512 - accuracy: 0.9824 - val_loss: 0.2480 - val_accuracy: 0.9457
# Epoch 21/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0352 - accuracy: 0.9844 - val_loss: 0.2522 - val_accuracy: 0.9376
# Epoch 22/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0422 - accuracy: 0.9824 - val_loss: 0.2747 - val_accuracy: 0.9376
# Epoch 23/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0434 - accuracy: 0.9844 - val_loss: 0.2450 - val_accuracy: 0.9416
# Epoch 24/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0449 - accuracy: 0.9798 - val_loss: 0.2695 - val_accuracy: 0.9437
# Epoch 25/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0388 - accuracy: 0.9854 - val_loss: 0.2751 - val_accuracy: 0.9396
# Epoch 26/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0336 - accuracy: 0.9844 - val_loss: 0.3015 - val_accuracy: 0.9416
# Epoch 27/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0397 - accuracy: 0.9829 - val_loss: 0.3057 - val_accuracy: 0.9437
# Epoch 28/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0466 - accuracy: 0.9814 - val_loss: 0.2823 - val_accuracy: 0.9356
# Epoch 29/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0259 - accuracy: 0.9919 - val_loss: 0.2589 - val_accuracy: 0.9437
# Epoch 30/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0303 - accuracy: 0.9894 - val_loss: 0.2367 - val_accuracy: 0.9437
# Epoch 31/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0318 - accuracy: 0.9869 - val_loss: 0.2276 - val_accuracy: 0.9376
# Epoch 32/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0415 - accuracy: 0.9849 - val_loss: 0.2954 - val_accuracy: 0.9336
# Epoch 33/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0506 - accuracy: 0.9793 - val_loss: 0.2074 - val_accuracy: 0.9356
# Epoch 34/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0268 - accuracy: 0.9914 - val_loss: 0.2111 - val_accuracy: 0.9477
# Epoch 35/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.1975 - val_accuracy: 0.9396
# Epoch 36/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0147 - accuracy: 0.9914 - val_loss: 0.2467 - val_accuracy: 0.9416
# Epoch 37/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0204 - accuracy: 0.9924 - val_loss: 0.2643 - val_accuracy: 0.9437
# Epoch 38/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0242 - accuracy: 0.9879 - val_loss: 0.2933 - val_accuracy: 0.9376
# Epoch 39/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0259 - accuracy: 0.9909 - val_loss: 0.1908 - val_accuracy: 0.9537
# Epoch 40/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0215 - accuracy: 0.9899 - val_loss: 0.2272 - val_accuracy: 0.9477
# Epoch 41/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0209 - accuracy: 0.9919 - val_loss: 0.2294 - val_accuracy: 0.9457
# Epoch 42/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0186 - accuracy: 0.9914 - val_loss: 0.2197 - val_accuracy: 0.9437
# Epoch 43/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0154 - accuracy: 0.9919 - val_loss: 0.2333 - val_accuracy: 0.9437
# Epoch 44/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0188 - accuracy: 0.9924 - val_loss: 0.2119 - val_accuracy: 0.9416
# Epoch 45/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0253 - accuracy: 0.9909 - val_loss: 0.3275 - val_accuracy: 0.9376
# Epoch 46/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0414 - accuracy: 0.9859 - val_loss: 0.2016 - val_accuracy: 0.9477
# Epoch 47/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0234 - accuracy: 0.9894 - val_loss: 0.2690 - val_accuracy: 0.9396
# Epoch 48/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0356 - accuracy: 0.9864 - val_loss: 0.2147 - val_accuracy: 0.9437
# Epoch 49/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0228 - accuracy: 0.9909 - val_loss: 0.3132 - val_accuracy: 0.9376
# Epoch 50/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0224 - accuracy: 0.9914 - val_loss: 0.2050 - val_accuracy: 0.9376
# Epoch 51/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0231 - accuracy: 0.9884 - val_loss: 0.2315 - val_accuracy: 0.9457
# Epoch 52/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0301 - accuracy: 0.9844 - val_loss: 0.1961 - val_accuracy: 0.9577
# Epoch 53/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0402 - accuracy: 0.9859 - val_loss: 0.2252 - val_accuracy: 0.9296
# Epoch 54/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0234 - accuracy: 0.9919 - val_loss: 0.2435 - val_accuracy: 0.9437
# Epoch 55/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0229 - accuracy: 0.9909 - val_loss: 0.2436 - val_accuracy: 0.9416
# Epoch 56/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0158 - accuracy: 0.9934 - val_loss: 0.4163 - val_accuracy: 0.9356
# Epoch 57/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0316 - accuracy: 0.9879 - val_loss: 0.3065 - val_accuracy: 0.9296
# Epoch 58/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0357 - accuracy: 0.9919 - val_loss: 0.2404 - val_accuracy: 0.9416
# Epoch 59/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0442 - accuracy: 0.9849 - val_loss: 0.2967 - val_accuracy: 0.9416
# Epoch 60/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0189 - accuracy: 0.9950 - val_loss: 0.3470 - val_accuracy: 0.9276
# Epoch 61/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0205 - accuracy: 0.9919 - val_loss: 0.2094 - val_accuracy: 0.9497
# Epoch 62/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0149 - accuracy: 0.9960 - val_loss: 0.2814 - val_accuracy: 0.9437
# Epoch 63/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0077 - accuracy: 0.9965 - val_loss: 0.2783 - val_accuracy: 0.9437
# Epoch 64/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0206 - accuracy: 0.9924 - val_loss: 0.1928 - val_accuracy: 0.9396
# Epoch 65/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0125 - accuracy: 0.9940 - val_loss: 0.4290 - val_accuracy: 0.9235
# Epoch 66/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0113 - accuracy: 0.9950 - val_loss: 0.2569 - val_accuracy: 0.9437
# Epoch 67/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0056 - accuracy: 0.9970 - val_loss: 0.2950 - val_accuracy: 0.9416
# Epoch 68/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0144 - accuracy: 0.9940 - val_loss: 0.4100 - val_accuracy: 0.9356
# Epoch 69/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0098 - accuracy: 0.9960 - val_loss: 0.2566 - val_accuracy: 0.9416
# Epoch 70/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0156 - accuracy: 0.9955 - val_loss: 0.3494 - val_accuracy: 0.9376
# Epoch 71/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0100 - accuracy: 0.9960 - val_loss: 0.2450 - val_accuracy: 0.9396
# Epoch 72/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0168 - accuracy: 0.9934 - val_loss: 0.2993 - val_accuracy: 0.9437
# Epoch 73/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0314 - accuracy: 0.9899 - val_loss: 0.2246 - val_accuracy: 0.9457
# Epoch 74/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0185 - accuracy: 0.9919 - val_loss: 0.3024 - val_accuracy: 0.9416
# Epoch 75/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.2836 - val_accuracy: 0.9497
# Epoch 76/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0095 - accuracy: 0.9960 - val_loss: 0.2668 - val_accuracy: 0.9376
# Epoch 77/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0088 - accuracy: 0.9960 - val_loss: 0.3324 - val_accuracy: 0.9376
# Epoch 78/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0379 - accuracy: 0.9879 - val_loss: 0.3295 - val_accuracy: 0.9296
# Epoch 79/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0274 - accuracy: 0.9879 - val_loss: 0.1968 - val_accuracy: 0.9437
# Epoch 80/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0209 - accuracy: 0.9919 - val_loss: 0.2244 - val_accuracy: 0.9477
# Epoch 81/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.2013 - val_accuracy: 0.9598
# Epoch 82/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0095 - accuracy: 0.9940 - val_loss: 0.2425 - val_accuracy: 0.9416
# Epoch 83/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.3541 - val_accuracy: 0.9376
# Epoch 84/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0250 - accuracy: 0.9904 - val_loss: 0.2195 - val_accuracy: 0.9416
# Epoch 85/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0181 - accuracy: 0.9934 - val_loss: 0.2888 - val_accuracy: 0.9437
# Epoch 86/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0082 - accuracy: 0.9960 - val_loss: 0.2316 - val_accuracy: 0.9477
# Epoch 87/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0085 - accuracy: 0.9960 - val_loss: 0.2801 - val_accuracy: 0.9437
# Epoch 88/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0139 - accuracy: 0.9929 - val_loss: 0.3886 - val_accuracy: 0.9437
# Epoch 89/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0137 - accuracy: 0.9934 - val_loss: 0.3746 - val_accuracy: 0.9396
# Epoch 90/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0194 - accuracy: 0.9934 - val_loss: 0.3628 - val_accuracy: 0.9437
# Epoch 91/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.2682 - val_accuracy: 0.9416
# Epoch 92/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0219 - accuracy: 0.9945 - val_loss: 0.6735 - val_accuracy: 0.9356
# Epoch 93/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0214 - accuracy: 0.9914 - val_loss: 0.2495 - val_accuracy: 0.9497
# Epoch 94/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0200 - accuracy: 0.9919 - val_loss: 0.1988 - val_accuracy: 0.9416
# Epoch 95/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0238 - accuracy: 0.9909 - val_loss: 0.2739 - val_accuracy: 0.9457
# Epoch 96/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0335 - accuracy: 0.9854 - val_loss: 0.2379 - val_accuracy: 0.9155
# Epoch 97/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0236 - accuracy: 0.9919 - val_loss: 0.2969 - val_accuracy: 0.9416
# Epoch 98/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0191 - accuracy: 0.9924 - val_loss: 0.2502 - val_accuracy: 0.9457
# Epoch 99/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0216 - accuracy: 0.9924 - val_loss: 0.2602 - val_accuracy: 0.9396
# Epoch 100/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0324 - accuracy: 0.9919 - val_loss: 0.1980 - val_accuracy: 0.9537
# Epoch 101/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0267 - accuracy: 0.9884 - val_loss: 0.2315 - val_accuracy: 0.9537
# Epoch 102/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 0.2595 - val_accuracy: 0.9276
# Epoch 103/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0256 - accuracy: 0.9889 - val_loss: 0.2695 - val_accuracy: 0.9437
# Epoch 104/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0082 - accuracy: 0.9980 - val_loss: 0.2594 - val_accuracy: 0.9437
# Epoch 105/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.2826 - val_accuracy: 0.9336
# Epoch 106/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.2991 - val_accuracy: 0.9416
# Epoch 107/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0068 - accuracy: 0.9990 - val_loss: 0.3855 - val_accuracy: 0.9376
# Epoch 108/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0167 - accuracy: 0.9955 - val_loss: 0.3345 - val_accuracy: 0.9336
# Epoch 109/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.2534 - val_accuracy: 0.9396
# Epoch 110/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0118 - accuracy: 0.9955 - val_loss: 0.2247 - val_accuracy: 0.9416
# Epoch 111/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.3306 - val_accuracy: 0.9376
# Epoch 112/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0175 - accuracy: 0.9934 - val_loss: 0.2060 - val_accuracy: 0.9457
# Epoch 113/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0135 - accuracy: 0.9934 - val_loss: 0.2386 - val_accuracy: 0.9336
# Epoch 114/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0085 - accuracy: 0.9950 - val_loss: 0.3100 - val_accuracy: 0.9437
# Epoch 115/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0108 - accuracy: 0.9945 - val_loss: 0.3794 - val_accuracy: 0.9437
# Epoch 116/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0180 - accuracy: 0.9934 - val_loss: 0.2381 - val_accuracy: 0.9356
# Epoch 117/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.3214 - val_accuracy: 0.9296
# Epoch 118/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0066 - accuracy: 0.9965 - val_loss: 0.3341 - val_accuracy: 0.9416
# Epoch 119/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.2393 - val_accuracy: 0.9477
# Epoch 120/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0173 - accuracy: 0.9934 - val_loss: 0.2553 - val_accuracy: 0.9356
# Epoch 121/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0136 - accuracy: 0.9934 - val_loss: 0.3070 - val_accuracy: 0.9316
# Epoch 122/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0134 - accuracy: 0.9945 - val_loss: 0.2722 - val_accuracy: 0.9416
# Epoch 123/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.4291 - val_accuracy: 0.9356
# Epoch 124/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0278 - accuracy: 0.9909 - val_loss: 0.6196 - val_accuracy: 0.9235
# Epoch 125/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0265 - accuracy: 0.9894 - val_loss: 0.4100 - val_accuracy: 0.9296
# Epoch 126/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0089 - accuracy: 0.9955 - val_loss: 0.3388 - val_accuracy: 0.9376
# Epoch 127/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.4003 - val_accuracy: 0.9336
# Epoch 128/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.3466 - val_accuracy: 0.9396
# Epoch 129/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0091 - accuracy: 0.9975 - val_loss: 0.2939 - val_accuracy: 0.9437
# Epoch 130/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0103 - accuracy: 0.9960 - val_loss: 0.4558 - val_accuracy: 0.9316
# Epoch 131/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.3539 - val_accuracy: 0.9376
# Epoch 132/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0273 - accuracy: 0.9914 - val_loss: 0.4555 - val_accuracy: 0.9437
# Epoch 133/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0118 - accuracy: 0.9950 - val_loss: 0.3845 - val_accuracy: 0.9376
# Epoch 134/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0194 - accuracy: 0.9945 - val_loss: 0.3594 - val_accuracy: 0.9457
# Epoch 135/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0092 - accuracy: 0.9960 - val_loss: 0.3639 - val_accuracy: 0.9437
# Epoch 136/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.3660 - val_accuracy: 0.9517
# Epoch 137/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0066 - accuracy: 0.9970 - val_loss: 0.3336 - val_accuracy: 0.9477
# Epoch 138/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.3337 - val_accuracy: 0.9477
# Epoch 139/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.3828 - val_accuracy: 0.9416
# Epoch 140/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.3401 - val_accuracy: 0.9376
# Epoch 141/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.3765 - val_accuracy: 0.9396
# Epoch 142/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.3257 - val_accuracy: 0.9376
# Epoch 143/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0067 - accuracy: 0.9970 - val_loss: 0.4512 - val_accuracy: 0.9376
# Epoch 144/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.3713 - val_accuracy: 0.9356
# Epoch 145/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0148 - accuracy: 0.9929 - val_loss: 0.3706 - val_accuracy: 0.9416
# Epoch 146/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.3634 - val_accuracy: 0.9437
# Epoch 147/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0173 - accuracy: 0.9924 - val_loss: 0.4095 - val_accuracy: 0.9376
# Epoch 148/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0144 - accuracy: 0.9934 - val_loss: 0.3426 - val_accuracy: 0.9376
# Epoch 149/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0193 - accuracy: 0.9904 - val_loss: 0.2618 - val_accuracy: 0.9457
# Epoch 150/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0122 - accuracy: 0.9934 - val_loss: 0.3058 - val_accuracy: 0.9416
# Epoch 151/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0153 - accuracy: 0.9960 - val_loss: 0.3332 - val_accuracy: 0.9416
# Epoch 152/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0184 - accuracy: 0.9929 - val_loss: 0.2823 - val_accuracy: 0.9437
# Epoch 153/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0084 - accuracy: 0.9965 - val_loss: 0.3244 - val_accuracy: 0.9376
# Epoch 154/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.3495 - val_accuracy: 0.9376
# Epoch 155/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0043 - accuracy: 0.9975 - val_loss: 0.4247 - val_accuracy: 0.9416
# Epoch 156/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.3930 - val_accuracy: 0.9396
# Epoch 157/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0115 - accuracy: 0.9970 - val_loss: 0.3199 - val_accuracy: 0.9416
# Epoch 158/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0113 - accuracy: 0.9929 - val_loss: 0.3082 - val_accuracy: 0.9396
# Epoch 159/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.3015 - val_accuracy: 0.9537
# Epoch 160/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0051 - accuracy: 0.9975 - val_loss: 0.4034 - val_accuracy: 0.9376
# Epoch 161/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0035 - accuracy: 0.9980 - val_loss: 0.3850 - val_accuracy: 0.9497
# Epoch 162/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0043 - accuracy: 0.9975 - val_loss: 0.3417 - val_accuracy: 0.9457
# Epoch 163/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.4037 - val_accuracy: 0.9416
# Epoch 164/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.3800 - val_accuracy: 0.9437
# Epoch 165/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.4467 - val_accuracy: 0.9457
# Epoch 166/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0117 - accuracy: 0.9945 - val_loss: 0.4442 - val_accuracy: 0.9356
# Epoch 167/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0132 - accuracy: 0.9975 - val_loss: 0.3673 - val_accuracy: 0.9396
# Epoch 168/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0070 - accuracy: 0.9960 - val_loss: 0.4143 - val_accuracy: 0.9437
# Epoch 169/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0093 - accuracy: 0.9955 - val_loss: 0.4750 - val_accuracy: 0.9376
# Epoch 170/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0159 - accuracy: 0.9945 - val_loss: 0.4662 - val_accuracy: 0.9376
# Epoch 171/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0166 - accuracy: 0.9955 - val_loss: 0.4653 - val_accuracy: 0.9416
# Epoch 172/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0128 - accuracy: 0.9965 - val_loss: 0.3969 - val_accuracy: 0.9336
# Epoch 173/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0118 - accuracy: 0.9950 - val_loss: 0.2762 - val_accuracy: 0.9437
# Epoch 174/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0135 - accuracy: 0.9934 - val_loss: 0.3453 - val_accuracy: 0.9416
# Epoch 175/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0093 - accuracy: 0.9960 - val_loss: 0.4778 - val_accuracy: 0.9256
# Epoch 176/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.3284 - val_accuracy: 0.9396
# Epoch 177/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0127 - accuracy: 0.9955 - val_loss: 0.5085 - val_accuracy: 0.9396
# Epoch 178/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0181 - accuracy: 0.9934 - val_loss: 0.4792 - val_accuracy: 0.9316
# Epoch 179/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0221 - accuracy: 0.9934 - val_loss: 0.2492 - val_accuracy: 0.9477
# Epoch 180/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.3271 - val_accuracy: 0.9416
# Epoch 181/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 0.2521 - val_accuracy: 0.9437
# Epoch 182/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.3036 - val_accuracy: 0.9437
# Epoch 183/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.3176 - val_accuracy: 0.9437
# Epoch 184/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0085 - accuracy: 0.9960 - val_loss: 0.3443 - val_accuracy: 0.9336
# Epoch 185/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0128 - accuracy: 0.9945 - val_loss: 0.2823 - val_accuracy: 0.9396
# Epoch 186/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0115 - accuracy: 0.9955 - val_loss: 0.2183 - val_accuracy: 0.9497
# Epoch 187/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0114 - accuracy: 0.9955 - val_loss: 0.2971 - val_accuracy: 0.9457
# Epoch 188/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.3569 - val_accuracy: 0.9497
# Epoch 189/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0030 - accuracy: 0.9980 - val_loss: 0.4575 - val_accuracy: 0.9477
# Epoch 190/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.4630 - val_accuracy: 0.9336
# Epoch 191/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0119 - accuracy: 0.9950 - val_loss: 0.4692 - val_accuracy: 0.9175
# Epoch 192/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0085 - accuracy: 0.9960 - val_loss: 0.3968 - val_accuracy: 0.9256
# Epoch 193/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0235 - accuracy: 0.9934 - val_loss: 0.3399 - val_accuracy: 0.9336
# Epoch 194/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0201 - accuracy: 0.9924 - val_loss: 0.2898 - val_accuracy: 0.9396
# Epoch 195/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.2978 - val_accuracy: 0.9376
# Epoch 196/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.3151 - val_accuracy: 0.9396
# Epoch 197/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0054 - accuracy: 0.9970 - val_loss: 0.3354 - val_accuracy: 0.9477
# Epoch 198/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.3082 - val_accuracy: 0.9396
# Epoch 199/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0088 - accuracy: 0.9980 - val_loss: 0.2686 - val_accuracy: 0.9457
# Epoch 200/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0074 - accuracy: 0.9960 - val_loss: 0.2871 - val_accuracy: 0.9497
# Epoch 201/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.2592 - val_accuracy: 0.9336
# Epoch 202/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0069 - accuracy: 0.9970 - val_loss: 0.3451 - val_accuracy: 0.9396
# Epoch 203/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.3296 - val_accuracy: 0.9276
# Epoch 204/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.3885 - val_accuracy: 0.9396
# Epoch 205/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0082 - accuracy: 0.9955 - val_loss: 0.2745 - val_accuracy: 0.9376
# Epoch 206/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0052 - accuracy: 0.9970 - val_loss: 0.3380 - val_accuracy: 0.9437
# Epoch 207/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.3827 - val_accuracy: 0.9437
# Epoch 208/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.4066 - val_accuracy: 0.9497
# Epoch 209/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.4516 - val_accuracy: 0.9416
# Epoch 210/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0126 - accuracy: 0.9970 - val_loss: 0.4439 - val_accuracy: 0.9416
# Epoch 211/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.3310 - val_accuracy: 0.9396
# Epoch 212/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0049 - accuracy: 0.9975 - val_loss: 0.3678 - val_accuracy: 0.9457
# Epoch 213/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.4602 - val_accuracy: 0.9477
# Epoch 214/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0351 - accuracy: 0.9919 - val_loss: 0.2762 - val_accuracy: 0.9477
# Epoch 215/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.2739 - val_accuracy: 0.9477
# Epoch 216/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0079 - accuracy: 0.9965 - val_loss: 0.2904 - val_accuracy: 0.9437
# Epoch 217/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.4143 - val_accuracy: 0.9437
# Epoch 218/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.3820 - val_accuracy: 0.9537
# Epoch 219/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.2900 - val_accuracy: 0.9477
# Epoch 220/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0034 - accuracy: 0.9980 - val_loss: 0.3611 - val_accuracy: 0.9437
# Epoch 221/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.4278 - val_accuracy: 0.9437
# Epoch 222/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0079 - accuracy: 0.9955 - val_loss: 0.3801 - val_accuracy: 0.9396
# Epoch 223/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0081 - accuracy: 0.9960 - val_loss: 0.5149 - val_accuracy: 0.9376
# Epoch 224/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0250 - accuracy: 0.9929 - val_loss: 0.2979 - val_accuracy: 0.9497
# Epoch 225/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0150 - accuracy: 0.9924 - val_loss: 0.2798 - val_accuracy: 0.9457
# Epoch 226/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0081 - accuracy: 0.9965 - val_loss: 0.3777 - val_accuracy: 0.9416
# Epoch 227/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0050 - accuracy: 0.9970 - val_loss: 0.4128 - val_accuracy: 0.9376
# Epoch 228/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.4586 - val_accuracy: 0.9376
# Epoch 229/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0245 - accuracy: 0.9914 - val_loss: 0.3222 - val_accuracy: 0.9356
# Epoch 230/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0112 - accuracy: 0.9955 - val_loss: 0.3018 - val_accuracy: 0.9416
# Epoch 231/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 0.4597 - val_accuracy: 0.9356
# Epoch 232/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0121 - accuracy: 0.9945 - val_loss: 0.2743 - val_accuracy: 0.9557
# Epoch 233/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.3453 - val_accuracy: 0.9457
# Epoch 234/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0052 - accuracy: 0.9970 - val_loss: 0.4185 - val_accuracy: 0.9356
# Epoch 235/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0062 - accuracy: 0.9970 - val_loss: 0.4377 - val_accuracy: 0.9316
# Epoch 236/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0070 - accuracy: 0.9960 - val_loss: 0.2556 - val_accuracy: 0.9457
# Epoch 237/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0051 - accuracy: 0.9965 - val_loss: 0.3706 - val_accuracy: 0.9457
# Epoch 238/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0089 - accuracy: 0.9955 - val_loss: 0.3451 - val_accuracy: 0.9477
# Epoch 239/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0059 - accuracy: 0.9970 - val_loss: 0.3557 - val_accuracy: 0.9437
# Epoch 240/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0052 - accuracy: 0.9960 - val_loss: 0.3501 - val_accuracy: 0.9316
# Epoch 241/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.4074 - val_accuracy: 0.9396
# Epoch 242/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0060 - accuracy: 0.9970 - val_loss: 0.3319 - val_accuracy: 0.9477
# Epoch 243/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0027 - accuracy: 0.9985 - val_loss: 0.3350 - val_accuracy: 0.9497
# Epoch 244/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0097 - accuracy: 0.9955 - val_loss: 0.3800 - val_accuracy: 0.9457
# Epoch 245/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0073 - accuracy: 0.9960 - val_loss: 0.3548 - val_accuracy: 0.9437
# Epoch 246/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0077 - accuracy: 0.9965 - val_loss: 0.3615 - val_accuracy: 0.9376
# Epoch 247/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.2803 - val_accuracy: 0.9437
# Epoch 248/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.3291 - val_accuracy: 0.9416
# Epoch 249/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0055 - accuracy: 0.9970 - val_loss: 0.3353 - val_accuracy: 0.9416
# Epoch 250/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0029 - accuracy: 0.9985 - val_loss: 0.3511 - val_accuracy: 0.9437
# Epoch 251/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.3078 - val_accuracy: 0.9517
# Epoch 252/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0026 - accuracy: 0.9980 - val_loss: 0.4298 - val_accuracy: 0.9416
# Epoch 253/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.4601 - val_accuracy: 0.9396
# Epoch 254/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0135 - accuracy: 0.9924 - val_loss: 0.4189 - val_accuracy: 0.9437
# Epoch 255/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.3719 - val_accuracy: 0.9497
# Epoch 256/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.3397 - val_accuracy: 0.9517
# Epoch 257/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 0.3202 - val_accuracy: 0.9497
# Epoch 258/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.3107 - val_accuracy: 0.9517
# Epoch 259/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.2762 - val_accuracy: 0.9497
# Epoch 260/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0046 - accuracy: 0.9980 - val_loss: 0.3102 - val_accuracy: 0.9557
# Epoch 261/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.4672 - val_accuracy: 0.9296
# Epoch 262/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0047 - accuracy: 0.9980 - val_loss: 0.2997 - val_accuracy: 0.9477
# Epoch 263/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0034 - accuracy: 0.9980 - val_loss: 0.3695 - val_accuracy: 0.9497
# Epoch 264/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.3668 - val_accuracy: 0.9477
# Epoch 265/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0101 - accuracy: 0.9975 - val_loss: 0.3179 - val_accuracy: 0.9537
# Epoch 266/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0098 - accuracy: 0.9960 - val_loss: 0.2716 - val_accuracy: 0.9396
# Epoch 267/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.4044 - val_accuracy: 0.9477
# Epoch 268/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0090 - accuracy: 0.9960 - val_loss: 0.3004 - val_accuracy: 0.9517
# Epoch 269/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.3399 - val_accuracy: 0.9537
# Epoch 270/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.4192 - val_accuracy: 0.9497
# Epoch 271/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0054 - accuracy: 0.9975 - val_loss: 0.3051 - val_accuracy: 0.9497
# Epoch 272/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0049 - accuracy: 0.9995 - val_loss: 0.3484 - val_accuracy: 0.9557
# Epoch 273/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0061 - accuracy: 0.9970 - val_loss: 0.3278 - val_accuracy: 0.9497
# Epoch 274/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0064 - accuracy: 0.9970 - val_loss: 0.4043 - val_accuracy: 0.9497
# Epoch 275/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0063 - accuracy: 0.9970 - val_loss: 0.4862 - val_accuracy: 0.9437
# Epoch 276/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0088 - accuracy: 0.9960 - val_loss: 0.2363 - val_accuracy: 0.9557
# Epoch 277/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0025 - accuracy: 0.9985 - val_loss: 0.3255 - val_accuracy: 0.9537
# Epoch 278/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0059 - accuracy: 0.9970 - val_loss: 0.3753 - val_accuracy: 0.9457
# Epoch 279/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0048 - accuracy: 0.9965 - val_loss: 0.2940 - val_accuracy: 0.9517
# Epoch 280/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.4220 - val_accuracy: 0.9457
# Epoch 281/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.4382 - val_accuracy: 0.9437
# Epoch 282/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.4513 - val_accuracy: 0.9416
# Epoch 283/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0052 - accuracy: 0.9975 - val_loss: 0.4735 - val_accuracy: 0.9477
# Epoch 284/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.3330 - val_accuracy: 0.9437
# Epoch 285/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0094 - accuracy: 0.9980 - val_loss: 0.3344 - val_accuracy: 0.9497
# Epoch 286/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0062 - accuracy: 0.9970 - val_loss: 0.4219 - val_accuracy: 0.9376
# Epoch 287/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.2582 - val_accuracy: 0.9577
# Epoch 288/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.2838 - val_accuracy: 0.9517
# Epoch 289/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0049 - accuracy: 0.9975 - val_loss: 0.2953 - val_accuracy: 0.9598
# Epoch 290/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3805 - val_accuracy: 0.9497
# Epoch 291/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.4069 - val_accuracy: 0.9477
# Epoch 292/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0084 - accuracy: 0.9965 - val_loss: 0.2765 - val_accuracy: 0.9497
# Epoch 293/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.3690 - val_accuracy: 0.9537
# Epoch 294/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.3371 - val_accuracy: 0.9557
# Epoch 295/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.4013 - val_accuracy: 0.9537
# Epoch 296/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4317 - val_accuracy: 0.9497
# Epoch 297/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.2800 - val_accuracy: 0.9457
# Epoch 298/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.4043 - val_accuracy: 0.9396
# Epoch 299/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.4617 - val_accuracy: 0.9457
# Epoch 300/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0193 - accuracy: 0.9940 - val_loss: 0.2048 - val_accuracy: 0.9517
# Epoch 301/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0095 - accuracy: 0.9985 - val_loss: 0.3940 - val_accuracy: 0.9437
# Epoch 302/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0118 - accuracy: 0.9970 - val_loss: 0.4778 - val_accuracy: 0.9437
# Epoch 303/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0048 - accuracy: 0.9990 - val_loss: 0.3413 - val_accuracy: 0.9557
# Epoch 304/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0168 - accuracy: 0.9960 - val_loss: 0.2976 - val_accuracy: 0.9457
# Epoch 305/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0055 - accuracy: 0.9970 - val_loss: 0.3892 - val_accuracy: 0.9517
# Epoch 306/500
# 62/62 [==============================] - 4s 67ms/step - loss: 9.8200e-04 - accuracy: 1.0000 - val_loss: 0.4602 - val_accuracy: 0.9497
# Epoch 307/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0121 - accuracy: 0.9950 - val_loss: 0.4020 - val_accuracy: 0.9437
# Epoch 308/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.2440 - val_accuracy: 0.9497
# Epoch 309/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0241 - accuracy: 0.9909 - val_loss: 0.3056 - val_accuracy: 0.9517
# Epoch 310/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0042 - accuracy: 0.9980 - val_loss: 0.3878 - val_accuracy: 0.9497
# Epoch 311/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0048 - accuracy: 0.9980 - val_loss: 0.4448 - val_accuracy: 0.9497
# Epoch 312/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.3916 - val_accuracy: 0.9497
# Epoch 313/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0060 - accuracy: 0.9975 - val_loss: 0.3423 - val_accuracy: 0.9517
# Epoch 314/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0027 - accuracy: 0.9985 - val_loss: 0.3429 - val_accuracy: 0.9497
# Epoch 315/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0052 - accuracy: 0.9975 - val_loss: 0.3690 - val_accuracy: 0.9477
# Epoch 316/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0037 - accuracy: 0.9980 - val_loss: 0.2562 - val_accuracy: 0.9557
# Epoch 317/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0036 - accuracy: 0.9980 - val_loss: 0.3756 - val_accuracy: 0.9477
# Epoch 318/500
# 62/62 [==============================] - 4s 68ms/step - loss: 8.0980e-04 - accuracy: 0.9995 - val_loss: 0.3515 - val_accuracy: 0.9517
# Epoch 319/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0059 - accuracy: 0.9975 - val_loss: 0.3175 - val_accuracy: 0.9537
# Epoch 320/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.3325 - val_accuracy: 0.9517
# Epoch 321/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.2487 - val_accuracy: 0.9437
# Epoch 322/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0032 - accuracy: 0.9985 - val_loss: 0.3052 - val_accuracy: 0.9477
# Epoch 323/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0038 - accuracy: 0.9975 - val_loss: 0.3099 - val_accuracy: 0.9437
# Epoch 324/500
# 62/62 [==============================] - 4s 67ms/step - loss: 9.3510e-04 - accuracy: 1.0000 - val_loss: 0.3989 - val_accuracy: 0.9457
# Epoch 325/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.4918 - val_accuracy: 0.9517
# Epoch 326/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.4255 - val_accuracy: 0.9577
# Epoch 327/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0056 - accuracy: 0.9970 - val_loss: 0.3912 - val_accuracy: 0.9497
# Epoch 328/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.3778 - val_accuracy: 0.9557
# Epoch 329/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.6496 - val_accuracy: 0.9256
# Epoch 330/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0184 - accuracy: 0.9950 - val_loss: 0.5469 - val_accuracy: 0.9175
# Epoch 331/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.3480 - val_accuracy: 0.9497
# Epoch 332/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.3105 - val_accuracy: 0.9557
# Epoch 333/500
# ...
# Epoch 391/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.4219 - val_accuracy: 0.9517
# Epoch 392/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0054 - accuracy: 0.9975 - val_loss: 0.3409 - val_accuracy: 0.9336
# Epoch 393/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.3749 - val_accuracy: 0.9557
# Epoch 394/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0071 - accuracy: 0.9965 - val_loss: 0.2983 - val_accuracy: 0.9437
# Epoch 395/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.3375 - val_accuracy: 0.9477
# Epoch 396/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.3757 - val_accuracy: 0.9437
# Epoch 397/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.4323 - val_accuracy: 0.9457
# Epoch 398/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.3811 - val_accuracy: 0.9517
# Epoch 399/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.4054 - val_accuracy: 0.9537
# Epoch 400/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.3568 - val_accuracy: 0.9376
# Epoch 401/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.3645 - val_accuracy: 0.9517
# Epoch 402/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.3750 - val_accuracy: 0.9416
# Epoch 403/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.3880 - val_accuracy: 0.9537
# Epoch 404/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4507 - val_accuracy: 0.9537
# Epoch 405/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.3639 - val_accuracy: 0.9477
# Epoch 406/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0051 - accuracy: 0.9975 - val_loss: 0.4049 - val_accuracy: 0.9537
# Epoch 407/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.4609 - val_accuracy: 0.9477
# Epoch 408/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.5281 - val_accuracy: 0.9517
# Epoch 409/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.4804 - val_accuracy: 0.9477
# Epoch 410/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0049 - accuracy: 0.9975 - val_loss: 0.4243 - val_accuracy: 0.9477
# Epoch 411/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.3255 - val_accuracy: 0.9416
# Epoch 412/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.5729 - val_accuracy: 0.9396
# Epoch 413/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0016 - accuracy: 0.9990 - val_loss: 0.6148 - val_accuracy: 0.9396
# Epoch 414/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7141 - val_accuracy: 0.9457
# Epoch 415/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0164 - accuracy: 0.9955 - val_loss: 0.3160 - val_accuracy: 0.9517
# Epoch 416/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0082 - accuracy: 0.9965 - val_loss: 0.3325 - val_accuracy: 0.9517
# Epoch 417/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.2353 - val_accuracy: 0.9477
# Epoch 418/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.3459 - val_accuracy: 0.9457
# Epoch 419/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.4703 - val_accuracy: 0.9437
# Epoch 420/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0027 - accuracy: 0.9985 - val_loss: 0.5447 - val_accuracy: 0.9416
# Epoch 421/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.5367 - val_accuracy: 0.9477
# Epoch 422/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0026 - accuracy: 0.9985 - val_loss: 0.4614 - val_accuracy: 0.9497
# Epoch 423/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.3360 - val_accuracy: 0.9537
# Epoch 424/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0102 - accuracy: 0.9980 - val_loss: 0.5061 - val_accuracy: 0.9497
# Epoch 425/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.3476 - val_accuracy: 0.9396
# Epoch 426/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.3853 - val_accuracy: 0.9497
# Epoch 427/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0032 - accuracy: 0.9985 - val_loss: 0.3859 - val_accuracy: 0.9477
# Epoch 428/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.3542 - val_accuracy: 0.9517
# Epoch 429/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3440 - val_accuracy: 0.9477
# Epoch 430/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0017 - accuracy: 0.9990 - val_loss: 0.3870 - val_accuracy: 0.9497
# Epoch 431/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0028 - accuracy: 0.9985 - val_loss: 0.3817 - val_accuracy: 0.9557
# Epoch 432/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.6146 - val_accuracy: 0.9416
# Epoch 433/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0030 - accuracy: 0.9980 - val_loss: 0.4356 - val_accuracy: 0.9497
# Epoch 434/500
# 62/62 [==============================] - 4s 67ms/step - loss: 5.7240e-04 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.9477
# Epoch 435/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0050 - accuracy: 0.9975 - val_loss: 0.4964 - val_accuracy: 0.9537
# Epoch 436/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.3444 - val_accuracy: 0.9537
# Epoch 437/500
# 62/62 [==============================] - 4s 67ms/step - loss: 9.7628e-04 - accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.9557
# Epoch 438/500
# 62/62 [==============================] - 4s 67ms/step - loss: 6.8608e-04 - accuracy: 0.9995 - val_loss: 0.5867 - val_accuracy: 0.9437
# Epoch 439/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0067 - accuracy: 0.9970 - val_loss: 0.4421 - val_accuracy: 0.9557
# Epoch 440/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.3086 - val_accuracy: 0.9537
# Epoch 441/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.3513 - val_accuracy: 0.9537
# Epoch 442/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.4132 - val_accuracy: 0.9537
# Epoch 443/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.3872 - val_accuracy: 0.9557
# Epoch 444/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0012 - accuracy: 0.9990 - val_loss: 0.4007 - val_accuracy: 0.9537
# Epoch 445/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.4573 - val_accuracy: 0.9477
# Epoch 446/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0104 - accuracy: 0.9975 - val_loss: 0.4514 - val_accuracy: 0.9557
# Epoch 447/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.3165 - val_accuracy: 0.9457
# Epoch 448/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.3325 - val_accuracy: 0.9517
# Epoch 449/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.3679 - val_accuracy: 0.9517
# Epoch 450/500
# 62/62 [==============================] - 4s 67ms/step - loss: 2.5516e-04 - accuracy: 1.0000 - val_loss: 0.4293 - val_accuracy: 0.9477
# Epoch 451/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.4448 - val_accuracy: 0.9477
# Epoch 452/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.5805 - val_accuracy: 0.9457
# Epoch 453/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.4006 - val_accuracy: 0.9437
# Epoch 454/500
# 62/62 [==============================] - 4s 67ms/step - loss: 5.7218e-04 - accuracy: 1.0000 - val_loss: 0.4729 - val_accuracy: 0.9396
# Epoch 455/500
# 62/62 [==============================] - 4s 68ms/step - loss: 2.3724e-04 - accuracy: 1.0000 - val_loss: 0.4930 - val_accuracy: 0.9396
# Epoch 456/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.5431 - val_accuracy: 0.9457
# Epoch 457/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.3884 - val_accuracy: 0.9497
# Epoch 458/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.4528 - val_accuracy: 0.9497
# Epoch 459/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.4535 - val_accuracy: 0.9517
# Epoch 460/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0049 - accuracy: 0.9980 - val_loss: 0.3539 - val_accuracy: 0.9497
# Epoch 461/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0045 - accuracy: 0.9980 - val_loss: 0.4285 - val_accuracy: 0.9477
# Epoch 462/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.3968 - val_accuracy: 0.9477
# Epoch 463/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 0.4832 - val_accuracy: 0.9477
# Epoch 464/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0035 - accuracy: 0.9980 - val_loss: 0.5301 - val_accuracy: 0.9477
# Epoch 465/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.3856 - val_accuracy: 0.9457
# Epoch 466/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0016 - accuracy: 0.9990 - val_loss: 0.3824 - val_accuracy: 0.9517
# Epoch 467/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.4392 - val_accuracy: 0.9457
# Epoch 468/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0078 - accuracy: 0.9985 - val_loss: 0.4566 - val_accuracy: 0.9396
# Epoch 469/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.3842 - val_accuracy: 0.9497
# Epoch 470/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.5175 - val_accuracy: 0.9457
# Epoch 471/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.2621 - val_accuracy: 0.9557
# Epoch 472/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.3351 - val_accuracy: 0.9497
# Epoch 473/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.3417 - val_accuracy: 0.9457
# Epoch 474/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0031 - accuracy: 0.9985 - val_loss: 0.4062 - val_accuracy: 0.9517
# Epoch 475/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0064 - accuracy: 0.9975 - val_loss: 0.4450 - val_accuracy: 0.9437
# Epoch 476/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.4920 - val_accuracy: 0.9457
# Epoch 477/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0033 - accuracy: 0.9985 - val_loss: 0.5578 - val_accuracy: 0.9497
# Epoch 478/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.5681 - val_accuracy: 0.9477
# Epoch 479/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.5299 - val_accuracy: 0.9497
# Epoch 480/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.6483 - val_accuracy: 0.9497
# Epoch 481/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0017 - accuracy: 0.9990 - val_loss: 0.7267 - val_accuracy: 0.9497
# Epoch 482/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.3339 - val_accuracy: 0.9577
# Epoch 483/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.3832 - val_accuracy: 0.9477
# Epoch 484/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.3721 - val_accuracy: 0.9517
# Epoch 485/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0030 - accuracy: 0.9985 - val_loss: 0.3836 - val_accuracy: 0.9517
# Epoch 486/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.3348 - val_accuracy: 0.9477
# Epoch 487/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0019 - accuracy: 0.9990 - val_loss: 0.4695 - val_accuracy: 0.9497
# Epoch 488/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.4380 - val_accuracy: 0.9437
# Epoch 489/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0163 - accuracy: 0.9970 - val_loss: 0.2921 - val_accuracy: 0.9477
# Epoch 490/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0038 - accuracy: 0.9980 - val_loss: 0.2973 - val_accuracy: 0.9477
# Epoch 491/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0032 - accuracy: 0.9985 - val_loss: 0.3890 - val_accuracy: 0.9416
# Epoch 492/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0023 - accuracy: 0.9985 - val_loss: 0.3847 - val_accuracy: 0.9517
# Epoch 493/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0065 - accuracy: 0.9970 - val_loss: 0.4310 - val_accuracy: 0.9416
# Epoch 494/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.4725 - val_accuracy: 0.9497
# Epoch 495/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.6055 - val_accuracy: 0.9356
# Epoch 496/500
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.3209 - val_accuracy: 0.9598
# Epoch 497/500
# 62/62 [==============================] - 4s 68ms/step - loss: 8.3424e-04 - accuracy: 1.0000 - val_loss: 0.3420 - val_accuracy: 0.9577
# Epoch 498/500
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0024 - accuracy: 0.9985 - val_loss: 0.3924 - val_accuracy: 0.9577
# Epoch 499/500
# 62/62 [==============================] - 4s 68ms/step - loss: 3.7362e-04 - accuracy: 1.0000 - val_loss: 0.4154 - val_accuracy: 0.9557
# Epoch 500/500
# 62/62 [==============================] - 4s 67ms/step - loss: 5.3695e-04 - accuracy: 1.0000 - val_loss: 0.4292 - val_accuracy: 0.9557

# %%
# Save Model and Weights
model.save('ResNet50V2.h5')
model.save_weights('ResNet50V2_weights.hdf5')

# %%
# Load saved model
model = load_model('ResNet50V2.h5')

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% COVID')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% NonCOVID')
  plt.style.reload_library
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       251
#            1       0.94      0.97      0.96       246
#
#     accuracy                           0.96       497
#    macro avg       0.96      0.96      0.96       497
# weighted avg       0.96      0.96      0.96       497

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
#plt.savefig('mobilenetaug_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
#plt.savefig('inception_ct_loss.png')
plt.show()
